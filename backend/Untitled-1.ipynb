# %%
import sqlite3

conn = sqlite3.connect("conversations.db")
cur = conn.cursor()

cur.execute("SELECT * FROM conversation_threads;")
print(cur.fetchall())


conn.close()
# Out:
# [('15514378-725f-4442-be9d-d5bbaad2f949', 'Test rename', '2026-01-18T18:54:02.683073', '2026-01-18T19:08:18.838925', 4, 'What evidence supports dark matter?'), ('ced6f456-d60f-42f8-9840-d60a5d0d2e89', 'New Conversation', '2026-01-18T19:08:35.926395', '2026-01-18T19:15:14.900577', 2, 'test, return 123'), ('bbe9f374-0e45-4374-8411-dca6dd0053c4', 'New Conversation', '2026-01-18T19:12:26.618627', '2026-01-18T19:12:27.552793', 2, 'My name is ivan, what is yours?')]
